# %%
import pandas as pd
import math

# %%
data = pd.read_excel('cities.xlsx')
data
# Out:
#           city  latitude  longitude
# 0        Tokyo   35.6897   139.6922
# 1      Jakarta   -6.1750   106.8275
# 2        Delhi   28.6100    77.2300
# 3    Guangzhou   23.1300   113.2600
# 4       Mumbai   19.0761    72.8775
# ..         ...       ...        ...
# 195     Deyang   31.1289   104.3950
# 196    Taiyuan   37.8733   112.5425
# 197       Kano   12.0000     8.5167
# 198       Wuhu   31.3340   118.3622
# 199    Nanning   22.8192   108.3150
#
# [200 rows x 3 columns]

# %%
def haversine(latitude1, longitude1, latitude2, longitude2):
    radiusOfEarth = 6371
    latitude1_radians = math.radians(latitude1)
    longitude1_radians = math.radians(longitude1)
    latitude2_radians = math.radians(latitude2)
    longitude2_radians = math.radians(longitude2)

    delta_latitude = latitude2_radians - latitude1_radians
    delta_longitude = longitude2_radians - longitude1_radians

    angular_distance = math.sin(delta_latitude/2)**2 + math.cos(latitude1_radians) * math.cos(latitude2_radians) * math.sin(delta_longitude/2)**2
    actual_angular_distance = 2 * math.atan2(math.sqrt(angular_distance), math.sqrt(1 - angular_distance))

    distance_in_km = radiusOfEarth * actual_angular_distance
    return distance_in_km

# %%
def create_clusters(locations, radius):
    clusters = []

    for location in locations:
        assigned = False
        for cluster in clusters:
            if all(haversine(location[0], location[1], point[0], point[1]) <= radius for point in cluster):
                cluster.append(location)
                assigned = True
                break
        if not assigned:
            clusters.append([location])

    return clusters

# %%
radius = 1113.2
locations = [(row['latitude'], row['longitude']) for _, row in data.iterrows()]

clusters = create_clusters(locations, radius)

# %%
city_names = list(data['city'])

for iterater, cluster in enumerate(clusters):
    print("--------------------------------------------------------")
    print(f'Cluster {iterater + 1}: {len(cluster)} locations')
    for location in cluster:
        city_name = city_names[locations.index(location)]
        print(f'- City: {city_name}, Latitude: {location[0]}, Longitude: {location[1]}')
    print("--------------------------------------------------------")
    print("\n")
# Out:
# --------------------------------------------------------
# Cluster 1: 3 locations
# - City: Tokyo, Latitude: 35.6897, Longitude: 139.6922
# - City: Ōsaka, Latitude: 34.6939, Longitude: 135.5022
# - City: Nagoya, Latitude: 35.1833, Longitude: 136.9
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 2: 2 locations
# - City: Jakarta, Latitude: -6.175, Longitude: 106.8275
# - City: Surabaya, Latitude: -7.2458, Longitude: 112.7378
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 3: 4 locations
# - City: Delhi, Latitude: 28.61, Longitude: 77.23
# - City: Karachi, Latitude: 24.86, Longitude: 67.01
# - City: Lahore, Latitude: 31.5497, Longitude: 74.3436
# - City: Ahmedabad, Latitude: 23.03, Longitude: 72.58
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 4: 35 locations
# - City: Guangzhou, Latitude: 23.13, Longitude: 113.26
# - City: Shenzhen, Latitude: 22.535, Longitude: 114.054
# - City: Chongqing, Latitude: 29.55, Longitude: 106.5069
# - City: Dongguan, Latitude: 23.0475, Longitude: 113.7493
# - City: Wuhan, Latitude: 30.5872, Longitude: 114.2881
# - City: Foshan, Latitude: 23.0292, Longitude: 113.1056
# - City: Ganzhou, Latitude: 25.8292, Longitude: 114.9336
# - City: Shaoyang, Latitude: 27.2418, Longitude: 111.4725
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 25: 2 locations
# - City: Kuala Lumpur, Latitude: 3.1478, Longitude: 101.6953
# - City: Singapore, Latitude: 1.3, Longitude: 103.8
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 26: 2 locations
# - City: Chicago, Latitude: 41.8375, Longitude: -87.6866
# - City: Atlanta, Latitude: 33.7628, Longitude: -84.422
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 27: 3 locations
# - City: Hanoi, Latitude: 21.0283, Longitude: 105.8542
# - City: Hong Kong, Latitude: 22.3, Longitude: 114.2
# - City: Zhanjiang, Latitude: 21.1967, Longitude: 110.4031
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 28: 1 locations
# - City: Johannesburg, Latitude: -26.2044, Longitude: 28.0456
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 29: 2 locations
# - City: Bogotá, Latitude: 4.7111, Longitude: -74.0722
# - City: Timbío, Latitude: 2.3445, Longitude: -76.6839
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 30: 2 locations
# - City: Dar es Salaam, Latitude: -6.8161, Longitude: 39.2803
# - City: Nairobi, Latitude: -1.2864, Longitude: 36.8172
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 31: 5 locations
# - City: Shenyang, Latitude: 41.8025, Longitude: 123.4281
# - City: Suihua, Latitude: 46.6384, Longitude: 126.9808
# - City: Qiqihar, Latitude: 47.3398, Longitude: 123.9512
# - City: Changchun, Latitude: 43.9, Longitude: 125.2
# - City: Chifeng, Latitude: 42.2663, Longitude: 118.9223
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 32: 2 locations
# - City: Khartoum, Latitude: 15.5006, Longitude: 32.56
# - City: Jeddah, Latitude: 21.5433, Longitude: 39.1728
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 33: 1 locations
# - City: Riyadh, Latitude: 24.6333, Longitude: 46.7167
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 34: 1 locations
# - City: Santiago, Latitude: -33.4372, Longitude: -70.6506
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 35: 1 locations
# - City: Sūrat, Latitude: 21.1702, Longitude: 72.8311
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 36: 2 locations
# - City: Madrid, Latitude: 40.4169, Longitude: -3.7033
# - City: Barcelona, Latitude: 41.3825, Longitude: 2.1769
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 37: 4 locations
# - City: Qujing, Latitude: 25.5102, Longitude: 103.8029
# - City: Zhaotong, Latitude: 27.3328, Longitude: 103.7144
# - City: Yibin, Latitude: 28.7596, Longitude: 104.64
# - City: Kunming, Latitude: 25.0433, Longitude: 102.7061
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 38: 1 locations
# - City: Miami, Latitude: 25.784, Longitude: -80.2101
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 39: 2 locations
# - City: Dallas, Latitude: 32.7935, Longitude: -96.7667
# - City: Houston, Latitude: 29.786, Longitude: -95.3885
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 40: 1 locations
# - City: Rangoon, Latitude: 16.795, Longitude: 96.16
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 41: 1 locations
# - City: Abidjan, Latitude: 5.3167, Longitude: -4.0333
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 42: 2 locations
# - City: Sydney, Latitude: -33.8678, Longitude: 151.21
# - City: Melbourne, Latitude: -37.8142, Longitude: 144.9631
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 43: 1 locations
# - City: Casablanca, Latitude: 33.5333, Longitude: -7.5833
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 44: 2 locations
# - City: Zhangjiakou, Latitude: 40.8108, Longitude: 114.8811
# - City: Taiyuan, Latitude: 37.8733, Longitude: 112.5425
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 45: 1 locations
# - City: Ürümqi, Latitude: 43.8225, Longitude: 87.6125
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 46: 1 locations
# - City: Kabul, Latitude: 34.5253, Longitude: 69.1783
# --------------------------------------------------------
#
#
# --------------------------------------------------------
# Cluster 47: 1 locations
# - City: Mogadishu, Latitude: 2.0392, Longitude: 45.3419
# --------------------------------------------------------
